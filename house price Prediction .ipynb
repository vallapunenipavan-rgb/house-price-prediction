# %%
import pandas as pd
import numpy as np

# %%
path="/content/archive.zip"
df=pd.read_csv(path)

# %%
df.head()
# Out:
#    Price  Bedroom   Space  Room   Lot     Tax  Bathroom  Garage  Condition
# 0   53.0      2.0   967.0   5.0  39.0   652.0       1.5     0.0        0.0
# 1   55.0      2.0   815.0   5.0  33.0  1000.0       1.0     2.0        1.0
# 2   56.0      3.0   900.0   5.0  35.0   897.0       1.5     1.0        0.0
# 3   58.0      3.0  1007.0   6.0  24.0   964.0       1.5     2.0        0.0
# 4   64.0      3.0  1100.0   7.0  50.0  1099.0       1.5     1.5        0.0

# %%
missing_values_count = df.isnull().sum()
display("Missing values count per column:", missing_values_count)
# Out:
# 'Missing values count per column:'
# Price        0
# Bedroom      0
# Space        0
# Room         0
# Lot          0
# Tax          0
# Bathroom     0
# Garage       0
# Condition    0
# dtype: int64

# %%
median_lot=df.Lot.median()
df.Lot.fillna(median_lot, inplace=True)
# Out:
# /tmp/ipython-input-3127712510.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.Lot.fillna(median_lot, inplace=True)

# %%
median_betroom=df.Bathroom.median()
median_betroom
# Out:
# 1.5

# %%
median_bedroom = df.Bedroom.median()
df.Bedroom.fillna(median_bedroom, inplace=True)
# Out:
# /tmp/ipython-input-2434413894.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.Bedroom.fillna(median_bedroom, inplace=True)

# %%
median_price=df.Price.median()
df.Price.fillna(median_price, inplace=True)
# Out:
# /tmp/ipython-input-4211929130.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.Price.fillna(median_price, inplace=True)

# %%
median_Space=df.Space.median()
df.Space.fillna(median_Space, inplace=True)
# Out:
# /tmp/ipython-input-2161356591.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.Space.fillna(median_Space, inplace=True)

# %%
median_room=df.Room.median()
df.Room.fillna(median_room, inplace=True)
# Out:
# /tmp/ipython-input-394464424.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.Room.fillna(median_room, inplace=True)

# %%
median_batroom=df.Bathroom.median()
df.Bathroom.fillna(median_batroom, inplace=True)

# %%
median_tax=df.Tax.median()
df.Tax.fillna(median_tax, inplace=True)
# Out:
# /tmp/ipython-input-2446767994.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.Tax.fillna(median_tax, inplace=True)

# %%
median_condition=df.Condition.median()

df.Condition.fillna(median_condition, inplace=True)
# Out:
# /tmp/ipython-input-816142871.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.Condition.fillna(median_condition, inplace=True)

# %%
median_Garage=df.Garage.median()
df.Garage.fillna(median_Garage, inplace=True)

# %%
import matplotlib.pyplot as plt

# %%
from sklearn import linear_model
reg=linear_model.LinearRegression()
reg.fit(df[['Bedroom','Space','Room','Lot','Tax','Bathroom','Garage','Condition']],df.Price)
# Out:
# LinearRegression()

# %%
reg.predict([[2.0,967.0,5.0,39.0,652.0,1.5,0.0,	0.0]])
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([50.94132748])
